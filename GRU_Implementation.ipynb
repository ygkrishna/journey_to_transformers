# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Example sentence
text = "Bob single-handedly fought the enemy and died for his country. For his contributions, brave ______."

# Step 1: Preprocess the text
sentences = [text.lower()]  # Lowercase for consistency
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)

# Tokenize the sentence
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1  # Vocabulary size (+1 for padding token)
sequences = tokenizer.texts_to_sequences(sentences)

# Create input (X) and output (y) pairs for training
sequence = sequences[0]
X, y = [], []
for i in range(1, len(sequence)):
    X.append(sequence[:i])  # Input sequence up to the current word
    y.append(sequence[i])   # The next word

# Pad sequences to make them of equal length
max_len = max(len(seq) for seq in X)
X = pad_sequences(X, maxlen=max_len, padding='pre')
y = np.array(y)

# Step 2: Define the GRU model
embedding_dim = 100
hidden_dim = 128

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len),
    GRU(hidden_dim, return_sequences=False),  # GRU layer
    Dense(vocab_size, activation='softmax')   # Output layer
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Step 3: Train the model
model.fit(X, y, epochs=100, verbose=1)

# Step 4: Predict the next word
def predict_next_word(input_text, model, tokenizer, max_len):
    # Tokenize and pad the input text
    sequence = tokenizer.texts_to_sequences([input_text])[0]
    sequence = pad_sequences([sequence], maxlen=max_len, padding='pre')
    
    # Predict the next word
    predicted_index = np.argmax(model.predict(sequence), axis=-1)[0]
    for word, index in tokenizer.word_index.items():
        if index == predicted_index:
            return word
    return None

# Input for prediction
input_text = "bob single-handedly fought the enemy and died for his country. for his contributions, brave"
predicted_word = predict_next_word(input_text, model, tokenizer, max_len)
print(f"Predicted next word: {predicted_word}")
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 2.6390 - accuracy: 0.0000e+00
# Epoch 2/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.6246 - accuracy: 0.2857
# Epoch 3/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.6100 - accuracy: 0.5000
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5953 - accuracy: 0.6429
# Epoch 5/100
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5801 - accuracy: 0.6429
# Epoch 6/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5645 - accuracy: 0.6429
# Epoch 7/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5481 - accuracy: 0.6429
# Epoch 8/100
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5308 - accuracy: 0.6429
# Epoch 9/100
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5123 - accuracy: 0.6429
# Epoch 10/100
# 1/1 [==============================] - 0s 6ms/step - loss: 2.4924 - accuracy: 0.5714
# Epoch 11/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4709 - accuracy: 0.5714
# Epoch 12/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4475 - accuracy: 0.5714
# Epoch 13/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4218 - accuracy: 0.5714
# Epoch 14/100
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3934 - accuracy: 0.5000
# Epoch 15/100
# 1/1 [==============================] - 0s 9ms/step - loss: 2.3618 - accuracy: 0.5000
# Epoch 16/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3267 - accuracy: 0.4286
# Epoch 17/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.2873 - accuracy: 0.4286
# Epoch 18/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2431 - accuracy: 0.4286
# Epoch 19/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1935 - accuracy: 0.4286
# Epoch 20/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1381 - accuracy: 0.4286
# Epoch 21/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0769 - accuracy: 0.4286
# Epoch 22/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0104 - accuracy: 0.4286
# Epoch 23/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9392 - accuracy: 0.4286
# Epoch 24/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.8628 - accuracy: 0.3571
# Epoch 25/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7825 - accuracy: 0.3571
# Epoch 26/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7050 - accuracy: 0.3571
# Epoch 27/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.6312 - accuracy: 0.2857
# Epoch 28/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5519 - accuracy: 0.2857
# Epoch 29/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4691 - accuracy: 0.4286
# Epoch 30/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4029 - accuracy: 0.6429
# Epoch 31/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3567 - accuracy: 0.6429
# Epoch 32/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3010 - accuracy: 0.6429
# Epoch 33/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2474 - accuracy: 0.7857
# Epoch 34/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2093 - accuracy: 0.8571
# Epoch 35/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1581 - accuracy: 0.8571
# Epoch 36/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1135 - accuracy: 0.8571
# Epoch 37/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0757 - accuracy: 0.9286
# Epoch 38/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0275 - accuracy: 1.0000
# Epoch 39/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9967 - accuracy: 0.9286
# Epoch 40/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9505 - accuracy: 1.0000
# Epoch 41/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9202 - accuracy: 0.9286
# Epoch 42/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8766 - accuracy: 1.0000
# Epoch 43/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8460 - accuracy: 1.0000
# Epoch 44/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8050 - accuracy: 1.0000
# Epoch 45/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7736 - accuracy: 1.0000
# Epoch 46/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7363 - accuracy: 1.0000
# Epoch 47/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7046 - accuracy: 1.0000
# Epoch 48/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6716 - accuracy: 1.0000
# Epoch 49/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6400 - accuracy: 1.0000
# Epoch 50/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6112 - accuracy: 1.0000
# Epoch 51/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5802 - accuracy: 1.0000
# Epoch 52/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5536 - accuracy: 1.0000
# Epoch 53/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5235 - accuracy: 1.0000
# Epoch 54/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4969 - accuracy: 1.0000
# Epoch 55/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4693 - accuracy: 1.0000
# Epoch 56/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4428 - accuracy: 1.0000
# Epoch 57/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4185 - accuracy: 1.0000
# Epoch 58/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3936 - accuracy: 1.0000
# Epoch 59/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3713 - accuracy: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3491 - accuracy: 1.0000
# Epoch 61/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3275 - accuracy: 1.0000
# Epoch 62/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3075 - accuracy: 1.0000
# Epoch 63/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2875 - accuracy: 1.0000
# Epoch 64/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2687 - accuracy: 1.0000
# Epoch 65/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2512 - accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2341 - accuracy: 1.0000
# Epoch 67/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2183 - accuracy: 1.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2036 - accuracy: 1.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1895 - accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1765 - accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1645 - accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1532 - accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1426 - accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1330 - accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1240 - accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1155 - accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1078 - accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1007 - accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0941 - accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0879 - accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0822 - accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0770 - accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0722 - accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0677 - accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0636 - accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0598 - accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0530 - accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0500 - accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0472 - accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0446 - accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0423 - accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0312 - accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0284 - accuracy: 1.0000
# Predicted next word: brave
